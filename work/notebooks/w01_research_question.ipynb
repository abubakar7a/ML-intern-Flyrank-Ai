# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I chose the Refresh / Content Opportunity Scoring lane because its goal is to identify webpages that should be reviewed first for content updates. Websites often contain hundreds or thousands of pages, making manual review difficult and time-consuming. By analyzing observable signals such as impressions, clicks, CTR, average position, content age, and engagement metrics, I can build a ranking system that helps prioritize pages with the highest opportunity for improvement. I selected this lane because it has a clear business value, uses the starter dataset directly, and allows me to compare simple rule-based methods with machine learning models.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
Research Question:
Which webpages should be reviewed first for content refresh based on their search performance and engagement signals?

Decision:
The project helps decide which pages deserve priority for content review.

Action:
SEO or content teams review the highest-ranked pages and decide whether to refresh, expand, rewrite, or monitor them.

Cost of a wrong recommendation:
If the model recommends the wrong pages, the team may spend time and resources updating pages that do not need attention while ignoring pages that actually require improvement. This reduces the effectiveness of the content optimization process.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
### Quick Look at the Data

The starter dataset contains **30,000 content pages** with **44 features**, providing a good amount of information for analyzing content performance.

The average number of **90-day impressions is approximately 5,200.37**, showing that many pages have measurable search visibility.

The dataset contains **16,262 pages with a "down" trend direction**, meaning more than half of the pages are currently declining. This suggests there are many potential candidates for content review and refresh.

The average **CTR (Click-Through Rate) is approximately 0.51**, indicating that click performance varies across pages and could be improved for some content. These statistics show that the dataset is large enough and contains meaningful search performance signals to support the Refresh / Content Opportunity Scoring lane.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
This project identifies pages that appear to be good candidates for review based on observable search and engagement signals. It does not prove that refreshing a page will increase traffic or improve rankings. The recommendations are intended to support human decision-making rather than replace it. Any improvements after a refresh would require further evaluation or experimentation to establish a causal relationship.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
